# %%
import pandas as pd

exam = pd.read_csv('../sample-data/Doit_Python-main/Data/exam.csv')
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
# 추가한 변수를 pandas 함수에 바로 활용하기
exam.assign(
    total = exam['math'] + exam['english'] + exam['science']
).sort_values(by = 'total')
# Out:
#     id  nclass  math  english  science  total
# 8    9       3    20       98       15    133
# 13  14       4    48       87       12    147
# 11  12       3    45       85       32    162
# 4    5       2    25       80       65    170
# 3    4       1    30       98       58    186
# 9   10       3    50       98       45    193
# 7    8       2    90       78       25    193
# 10  11       3    65       65       65    195
# 0    1       1    50       98       50    198
# 2    3       1    45       86       78    209
# 12  13       4    46       98       65    209
# 14  15       4    75       56       78    209
# 6    7       2    80       90       45    215
# 1    2       1    60       97       60    217
# 19  20       5    78       83       58    219
# 15  16       4    58       98       65    221
# 16  17       5    65       68       98    231
# 5    6       2    50       89       98    237
# 18  19       5    89       68       87    244
# ...
